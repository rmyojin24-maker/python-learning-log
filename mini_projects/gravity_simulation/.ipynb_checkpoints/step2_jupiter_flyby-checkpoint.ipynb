# %%
import numpy as np
import matplotlib.pyplot as plt

# ----------------------------
# パラメータ
# ----------------------------
mu_sun = 1.0
mu_jupiter = 0.02

R_jupiter = 2.0          # 木星の軌道半径
omega_jupiter = np.sqrt(mu_sun / R_jupiter**3)  # 円運動の角速度

dt = 0.001
steps = 30000

# ----------------------------
# 木星の位置を返す関数
# ----------------------------
def jupiter_position(t):
    xj = R_jupiter * np.cos(omega_jupiter * t)
    yj = R_jupiter * np.sin(omega_jupiter * t)
    return xj, yj

# ----------------------------
# シミュレーション関数
# ----------------------------
def simulate_flyby(mu_sun, mu_jupiter, x, y, vx, vy, dt, steps):
    x_list = []
    y_list = []
    xj_list = []
    yj_list = []

    t = 0.0

    for _ in range(steps):
        # 木星の位置
        xj, yj = jupiter_position(t)

        # 太陽までの距離
        r_sun = np.sqrt(x**2 + y**2)

        # 木星までの距離
        dxj = x - xj
        dyj = y - yj
        r_jup = np.sqrt(dxj**2 + dyj**2)

        # 太陽からの加速度
        ax_sun = -mu_sun * x / r_sun**3
        ay_sun = -mu_sun * y / r_sun**3

        # 木星からの加速度
        ax_jup = -mu_jupiter * dxj / r_jup**3
        ay_jup = -mu_jupiter * dyj / r_jup**3

        # 合計加速度
        ax = ax_sun + ax_jup
        ay = ay_sun + ay_jup

        # 速度更新
        vx += ax * dt
        vy += ay * dt

        # 位置更新
        x += vx * dt
        y += vy * dt

        # 保存
        x_list.append(x)
        y_list.append(y)
        xj_list.append(xj)
        yj_list.append(yj)

        t += dt

    return x_list, y_list, xj_list, yj_list

# ----------------------------
# 初期条件
# ----------------------------
x0 = 1.2
y0 = -1.5
vx0 = 0.8
vy0 = 0.6

# ----------------------------
# 実行
# ----------------------------
x_list, y_list, xj_list, yj_list = simulate_flyby(
    mu_sun, mu_jupiter, x0, y0, vx0, vy0, dt, steps
)

# ----------------------------
# 描画
# ----------------------------
plt.figure(figsize=(7, 7))
plt.plot(x_list, y_list, label="spacecraft")
plt.plot(xj_list, yj_list, "--", label="jupiter orbit")
plt.scatter(0, 0, s=250, color="orange", label="Sun")
plt.scatter(xj_list[-1], yj_list[-1], s=120, color="brown", label="Jupiter (final)")
plt.axis("equal")
plt.grid()
plt.legend()
plt.title("Step 2: Jupiter Flyby (2D)")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
plt.figure(figsize=(8, 8))

cases = [
    (1.2, -1.5, 0.8, 0.6),
    (1.2, -1.7, 0.8, 0.6),
    (1.2, -1.9, 0.8, 0.6),
    (1.2, -2.1, 0.8, 0.6),
]

for i, (x0, y0, vx0, vy0) in enumerate(cases, 1):
    x_list, y_list, xj_list, yj_list = simulate_flyby(
        mu_sun, mu_jupiter, x0, y0, vx0, vy0, dt, steps
    )
    plt.plot(x_list, y_list, label=f"case {i}: y0={y0}")

plt.plot(xj_list, yj_list, "--", label="Jupiter orbit")
plt.scatter(0, 0, s=250, color="orange", label="Sun")
plt.axis("equal")
plt.grid()
plt.legend()
plt.title("Flyby trial: changing y0")
plt.show()

# %%
mu_jupiter = 0.1  # 強くする

x0 = 2.0
y0 = -0.5
vx0 = 0.0
vy0 = 0.8

# %%
plt.figure(figsize=(7, 7))
plt.plot(x_list, y_list, label="spacecraft")
plt.plot(xj_list, yj_list, "--", label="jupiter orbit")
plt.scatter(0, 0, s=250, color="orange", label="Sun")
plt.scatter(xj_list[-1], yj_list[-1], s=120, color="brown", label="Jupiter (final)")
plt.axis("equal")
plt.grid()
plt.legend()
plt.title("Step 2: Jupiter Flyby (2D)")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
x_list, y_list, xj_list, yj_list = simulate_flyby(
    mu_sun, mu_jupiter, x0, y0, vx0, vy0, dt, steps
)

# ----------------------------
# 描画
# ----------------------------
plt.figure(figsize=(7, 7))
plt.plot(x_list, y_list, label="spacecraft")
plt.plot(xj_list, yj_list, "--", label="jupiter orbit")
plt.scatter(0, 0, s=250, color="orange", label="Sun")
plt.scatter(xj_list[-1], yj_list[-1], s=120, color="brown", label="Jupiter (final)")
plt.axis("equal")
plt.grid()
plt.legend()
plt.title("Step 2: Jupiter Flyby (2D)")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
mu_jupiter = 0.02  # 戻した
x_list, y_list, xj_list, yj_list = simulate_flyby(
    mu_sun, mu_jupiter, x0, y0, vx0, vy0, dt, steps
)

# ----------------------------
# 描画
# ----------------------------
plt.figure(figsize=(7, 7))
plt.plot(x_list, y_list, label="spacecraft")
plt.plot(xj_list, yj_list, "--", label="jupiter orbit")
plt.scatter(0, 0, s=250, color="orange", label="Sun")
plt.scatter(xj_list[-1], yj_list[-1], s=120, color="brown", label="Jupiter (final)")
plt.axis("equal")
plt.grid()
plt.legend()
plt.title("Step 2: Jupiter Flyby (2D)")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
x0 = 2.5
y0 = -1
vx0 = 0.0
vy0 = 0.8
x_list, y_list, xj_list, yj_list = simulate_flyby(
    mu_sun, mu_jupiter, x0, y0, vx0, vy0, dt, steps
)

# ----------------------------
# 描画
# ----------------------------
plt.figure(figsize=(7, 7))
plt.plot(x_list, y_list, label="spacecraft")
plt.plot(xj_list, yj_list, "--", label="jupiter orbit")
plt.scatter(0, 0, s=250, color="orange", label="Sun")
plt.scatter(xj_list[-1], yj_list[-1], s=120, color="brown", label="Jupiter (final)")
plt.axis("equal")
plt.grid()
plt.legend()
plt.title("Step 2: Jupiter Flyby (2D)")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
plt.figure(figsize=(8, 8))

cases = [
    (2.1, -0.8, 0.0, 0.8, "below Jupiter"),
    (2.1,  0.8, 0.0, 0.8, "above Jupiter"),
    (2.1, -0.8, 0.0, -0.8, "below, opposite velocity"),
    (2.1,  0.8, 0.0, -0.8, "above, opposite velocity"),
]

for x0, y0, vx0, vy0, label in cases:
    x_list, y_list, xj_list, yj_list = simulate_flyby(
        mu_sun, mu_jupiter, x0, y0, vx0, vy0, dt, steps
    )
    plt.plot(x_list, y_list, label=label)
    plt.scatter(x0, y0, s=50)

plt.plot(xj_list, yj_list, "--", label="Jupiter orbit")
plt.scatter(0, 0, s=250, color="orange", label="Sun")
plt.axis("equal")
plt.grid()
plt.legend()
plt.title("Compare flyby direction")
plt.show()

# %%
plt.figure(figsize=(8, 8))

cases = [
    (2, -0.5, 0, 0.8, "below Jupiter"),
    (2, 0.5, 0, 0.8, "above Jupiter"),
    (2, -0.5, 0, -0.8, "below, opposite velocity"),
    (2, 0.5, 0, -0.8, "above, opposite velocity"),
]

for x0, y0, vx0, vy0, label in cases:
    x_list, y_list, xj_list, yj_list = simulate_flyby(
        mu_sun, mu_jupiter, x0, y0, vx0, vy0, dt, steps
    )
    plt.plot(x_list, y_list, label=label)
    plt.scatter(x0, y0, s=50)

plt.plot(xj_list, yj_list, "--", label="Jupiter orbit")
plt.scatter(0, 0, s=250, color="orange", label="Sun")
plt.axis("equal")
plt.grid()
plt.legend()
plt.title("Compare flyby direction")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# ----------------------------
# パラメータ
# ----------------------------
mu_sun = 1.0
mu_jupiter = 0.02

R_jupiter = 2.0          # 木星の軌道半径
omega_jupiter = np.sqrt(mu_sun / R_jupiter**3)  # 円運動の角速度

dt = 0.001
steps = 30000

# ----------------------------
# 木星の位置を返す関数
# ----------------------------
def jupiter_position(t):
    xj = R_jupiter * np.cos(omega_jupiter * t)
    yj = R_jupiter * np.sin(omega_jupiter * t)
    return xj, yj

# ----------------------------
# シミュレーション関数
# ----------------------------
def simulate_flyby(mu_sun, mu_jupiter, x, y, vx, vy, dt, steps):
    x_list = []
    y_list = []
    xj_list = []
    yj_list = []
    vx_list = []
    vy_list = []
    v_list = []

    t = 0.0

    for _ in range(steps):
        # 木星の位置
        xj, yj = jupiter_position(t)

        # 太陽までの距離
        r_sun = np.sqrt(x**2 + y**2)

        # 木星までの距離
        dxj = x - xj
        dyj = y - yj
        r_jup = np.sqrt(dxj**2 + dyj**2)

        # 太陽からの加速度
        ax_sun = -mu_sun * x / r_sun**3
        ay_sun = -mu_sun * y / r_sun**3

        # 木星からの加速度
        ax_jup = -mu_jupiter * dxj / r_jup**3
        ay_jup = -mu_jupiter * dyj / r_jup**3

        # 合計加速度
        ax = ax_sun + ax_jup
        ay = ay_sun + ay_jup

        # 速度更新
        vx += ax * dt
        vy += ay * dt
        v = np.sqrt(vx**2 + vy**2)

        # 位置更新
        x += vx * dt
        y += vy * dt

        # 保存
        x_list.append(x)
        y_list.append(y)
        xj_list.append(xj)
        yj_list.append(yj)
        vx_list.append(vx)
        vy_list.append(vy)
        v_list.append(v)

        t += dt

    return x_list, y_list, xj_list, yj_list, v_list

# ----------------------------
# 初期条件
# ----------------------------
x0 = 1.2
y0 = -1.5
vx0 = 0.8
vy0 = 0.6

# ----------------------------
# 実行
# ----------------------------
x_list, y_list, xj_list, yj_list, v_list= simulate_flyby(
    mu_sun, mu_jupiter, x0, y0, vx0, vy0, dt, steps
)

# ----------------------------
# 描画
# ----------------------------
plt.figure(figsize=(7, 7))
plt.plot(x_list, y_list, label="spacecraft")
plt.plot(xj_list, yj_list, "--", label="jupiter orbit")
plt.scatter(0, 0, s=250, color="orange", label="Sun")
plt.scatter(xj_list[-1], yj_list[-1], s=120, color="brown", label="Jupiter (final)")
plt.axis("equal")
plt.grid()
plt.legend()
plt.title("Step 2: Jupiter Flyby (2D)")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
time = np.arange(len(v_list)) * dt

plt.figure(figsize=(8, 4))
plt.plot(time, v_list)
plt.grid()
plt.title("Speed Change During Jupiter Flyby")
plt.xlabel("Time")
plt.ylabel("Speed")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# ----------------------------
# パラメータ
# ----------------------------
mu_sun = 1.0
mu_jupiter = 0.02

R_jupiter = 2.0          # 木星の軌道半径
omega_jupiter = np.sqrt(mu_sun / R_jupiter**3)  # 円運動の角速度

dt = 0.001
steps = 30000

# ----------------------------
# 木星の位置を返す関数
# ----------------------------
def jupiter_position(t):
    xj = R_jupiter * np.cos(omega_jupiter * t)
    yj = R_jupiter * np.sin(omega_jupiter * t)
    return xj, yj

# ----------------------------
# シミュレーション関数
# ----------------------------
def simulate_flyby(mu_sun, mu_jupiter, x, y, vx, vy, dt, steps):
    x_list = []
    y_list = []
    xj_list = []
    yj_list = []
    vx_list = []
    vy_list = []
    v_list = []
    r_jup_list = []

    t = 0.0

    for _ in range(steps):
        # 木星の位置
        xj, yj = jupiter_position(t)

        # 太陽までの距離
        r_sun = np.sqrt(x**2 + y**2)

        # 木星までの距離
        dxj = x - xj
        dyj = y - yj
        r_jup = np.sqrt(dxj**2 + dyj**2)

        # 太陽からの加速度
        ax_sun = -mu_sun * x / r_sun**3
        ay_sun = -mu_sun * y / r_sun**3

        # 木星からの加速度
        ax_jup = -mu_jupiter * dxj / r_jup**3
        ay_jup = -mu_jupiter * dyj / r_jup**3

        # 合計加速度
        ax = ax_sun + ax_jup
        ay = ay_sun + ay_jup

        # 速度更新
        vx += ax * dt
        vy += ay * dt
        v = np.sqrt(vx**2 + vy**2)

        # 位置更新
        x += vx * dt
        y += vy * dt

        # 保存
        x_list.append(x)
        y_list.append(y)
        xj_list.append(xj)
        yj_list.append(yj)
        vx_list.append(vx)
        vy_list.append(vy)
        v_list.append(v)
        r_jup_list.append(r_jup)

        t += dt

    return x_list, y_list, xj_list, yj_list, v_list, r_jup_list

# ----------------------------
# 初期条件
# ----------------------------
x0 = 1.2
y0 = -1.5
vx0 = 0.8
vy0 = 0.6

# ----------------------------
# 実行
# ----------------------------
initial_conditions = [
    (1.2, -1.5, 0.8, 0.6),
    (1.4, -1.2, 0.7, 0.7),
    (1.5, -1.0, 0.6, 0.8),
    (1.6, -0.8, 0.5, 0.9),
]

plt.figure(figsize=(7, 7))

for i, (x0, y0, vx0, vy0) in enumerate(initial_conditions):
    x_list, y_list, xj_list, yj_list, v_list, r_jup_list = simulate_flyby(
        mu_sun, mu_jupiter, x0, y0, vx0, vy0, dt, steps
    )
    min_dist = min(r_jup_list)
    print(f"case {i+1}: min distance to Jupiter = {min_dist:.3f}")
    plt.plot(x_list, y_list, label=f"case {i+1}")

plt.plot(xj_list, yj_list, "--", label="jupiter orbit")
plt.scatter(0, 0, s=250, color="orange", label="Sun")
plt.scatter(xj_list[-1], yj_list[-1], s=120, color="brown", label="Jupiter (final)")

plt.axis("equal")
plt.grid()
plt.legend()
plt.title("Multiple Flyby Trajectories")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
# Out:
# case 1: min distance to Jupiter = 1.491
# case 2: min distance to Jupiter = 1.103
# case 3: min distance to Jupiter = 0.781
# case 4: min distance to Jupiter = 0.471

# %%
initial_conditions = [
    (1.6, -0.8, 0.5, 0.9),
    (1.7, -0.7, 0.5, 0.9),
    (1.8, -0.6, 0.5, 0.9),
    (1.9, -0.4, 0.5, 0.9),
]

plt.figure(figsize=(7, 7))

for i, (x0, y0, vx0, vy0) in enumerate(initial_conditions):
    x_list, y_list, xj_list, yj_list, v_list, r_jup_list = simulate_flyby(
        mu_sun, mu_jupiter, x0, y0, vx0, vy0, dt, steps
    )
    min_dist = min(r_jup_list)
    print(f"case {i+1}: min distance to Jupiter = {min_dist:.3f}")
    plt.plot(x_list, y_list, label=f"case {i+1}")

plt.plot(xj_list, yj_list, "--", label="jupiter orbit")
plt.scatter(0, 0, s=250, color="orange", label="Sun")
plt.scatter(xj_list[-1], yj_list[-1], s=120, color="brown", label="Jupiter (final)")

plt.axis("equal")
plt.grid()
plt.legend()
plt.title("Multiple Flyby Trajectories")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
# Out:
# case 1: min distance to Jupiter = 0.471
# case 2: min distance to Jupiter = 0.469
# case 3: min distance to Jupiter = 0.446
# case 4: min distance to Jupiter = 0.317

# %%
initial_conditions = [
    (-0.1, -2.4, -0.39, 0.98),
    (1.22, -1.58, 0.01, -0.55),
    (1.8, -0.6, 0.2, 0.9),
    (1.9, -0.4, 0.5, 0.9),
]

plt.figure(figsize=(7, 7))

for i, (x0, y0, vx0, vy0) in enumerate(initial_conditions):
    x_list, y_list, xj_list, yj_list, v_list, r_jup_list = simulate_flyby(
        mu_sun, mu_jupiter, x0, y0, vx0, vy0, dt, steps
    )
    min_dist = min(r_jup_list)
    print(f"case {i+1}: min distance to Jupiter = {min_dist:.3f}")
    plt.plot(x_list, y_list, label=f"case {i+1}")

plt.plot(xj_list, yj_list, "--", label="jupiter orbit")
plt.scatter(0, 0, s=250, color="orange", label="Sun")
plt.scatter(xj_list[-1], yj_list[-1], s=120, color="brown", label="Jupiter (final)")

plt.axis("equal")
plt.grid()
plt.legend()
plt.title("Multiple Flyby Trajectories")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
# Out:
# case 1: min distance to Jupiter = 0.713
# case 2: min distance to Jupiter = 0.564
# case 3: min distance to Jupiter = 0.072
# case 4: min distance to Jupiter = 0.317

# %%
# ----------------------------
# 初期条件
# ----------------------------(1.8, -0.6, 0.2, 0.9)
x0 = 1.8
y0 = -0.6
vx0 = 0.2
vy0 = 0.9

# ----------------------------
# 実行
# ----------------------------
x_list, y_list, xj_list, yj_list, v_list, r_jup_list= simulate_flyby(
    mu_sun, mu_jupiter, x0, y0, vx0, vy0, dt, steps
)
# ----------------------------
# 描画
# ----------------------------
plt.figure(figsize=(7, 7))
plt.plot(x_list, y_list, label="spacecraft")
plt.plot(xj_list, yj_list, "--", label="jupiter orbit")
plt.scatter(0, 0, s=250, color="orange", label="Sun")
plt.scatter(xj_list[-1], yj_list[-1], s=120, color="brown", label="Jupiter (final)")
plt.axis("equal")
plt.grid()
plt.legend()
plt.title("Step 2: Jupiter Flyby (2D)")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
time = np.arange(len(v_list)) * dt

plt.figure(figsize=(8, 4))
plt.plot(time, v_list)
plt.grid()
plt.title("Speed Change During Jupiter Flyby")
plt.xlabel("Time")
plt.ylabel("Speed")
plt.show()
print("max speed:", max(v_list))
print("initial speed:", v_list[0])
plt.plot(r_jup_list)
plt.title("Distance to Jupiter")
plt.show()
# Out:
# max speed: 1.4776703257686898
# initial speed: 0.9220328032886401
